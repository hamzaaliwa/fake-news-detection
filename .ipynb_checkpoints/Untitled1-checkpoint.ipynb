# %%
import re
import string
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
dfake = pd.read_csv('C:\\Users\\hamza\\Desktop\\projet de stage\\Fake.csv\\Fake.csv')
dtrue = pd.read_csv('C:\\Users\\hamza\\Desktop\\projet de stage\\True.csv\\True.csv')
dmelangetrain = pd.read_csv('C:\\Users\\hamza\\Desktop\\projet de stage\\fake-news\\train.csv')
dmelangetest = pd.read_csv('C:\\Users\\hamza\\Desktop\\projet de stage\\fake-news\\test.csv')

# %%
dfake = dfake.dropna()
dtrue = dtrue.dropna()
dmelangetest = dmelangetest.dropna()
dmelangetrain = dmelangetrain.dropna()

# %%
datafinal = pd.concat([dmelangetrain, dmelangetest], ignore_index=True)
datafinal.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...    1.0
# 1  Ever get the feeling your life circles the rou...    0.0
# 2  Why the Truth Might Get You Fired October 29, ...    1.0
# 3  Videos 15 Civilians Killed In Single US Airstr...    1.0
# 4  Print \nAn Iranian woman has been sentenced to...    1.0

# %%
dtrue.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
dtrue['label'] = 1
dtrue.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
dfake['label'] = 0
dfake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
datafinal2 = pd.concat([dfake, dtrue], ignore_index=True)
datafinal2
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
datafinal = datafinal.drop(['title', 'id', 'author'] , axis=1)
datafinal2 = datafinal2.drop(['title', 'date', 'subject'] , axis=1)

# %%
datafinal
# Out:
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...    1.0
# 1      Ever get the feeling your life circles the rou...    0.0
# 2      Why the Truth Might Get You Fired October 29, ...    1.0
# 3      Videos 15 Civilians Killed In Single US Airstr...    1.0
# 4      Print \nAn Iranian woman has been sentenced to...    1.0
# ...                                                  ...    ...
# 22855  Pres. Trump on if “tapes” exist of his convers...    NaN
# 22856  Of all the dysfunctions that plague the world’...    NaN
# 22857  WASHINGTON  —   Gov. John Kasich of Ohio on Tu...    NaN
# 22858  Good morning. (Want to get California Today by...    NaN
# 22859  Perhaps you’ve seen the new TV series whose pi...    NaN
#
# [22860 rows x 2 columns]

# %%
datafinal2
# Out:
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 44895  MINSK (Reuters) - In the shadow of disused Sov...      1
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1
#
# [44898 rows x 2 columns]

# %%
datafinal = pd.concat([datafinal, datafinal2], ignore_index=True)
datafinal
# Out:
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...    1.0
# 1      Ever get the feeling your life circles the rou...    0.0
# 2      Why the Truth Might Get You Fired October 29, ...    1.0
# 3      Videos 15 Civilians Killed In Single US Airstr...    1.0
# 4      Print \nAn Iranian woman has been sentenced to...    1.0
# ...                                                  ...    ...
# 67753  BRUSSELS (Reuters) - NATO allies on Tuesday we...    1.0
# 67754  LONDON (Reuters) - LexisNexis, a provider of l...    1.0
# 67755  MINSK (Reuters) - In the shadow of disused Sov...    1.0
# 67756  MOSCOW (Reuters) - Vatican Secretary of State ...    1.0
# 67757  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...    1.0
#
# [67758 rows x 2 columns]

# %%
#dataset finale

# %%
def transform_value(value): 
    if value == 1 or value == 1.0:
        return "False news"
    elif value == 0 or value == 0.0:
        return "True news"
    else:
        return value
datafinal['label'] = datafinal['label'].apply(transform_value)
datafinal
# Out:
#                                                     text       label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...  False news
# 1      Ever get the feeling your life circles the rou...   True news
# 2      Why the Truth Might Get You Fired October 29, ...  False news
# 3      Videos 15 Civilians Killed In Single US Airstr...  False news
# 4      Print \nAn Iranian woman has been sentenced to...  False news
# ...                                                  ...         ...
# 67753  BRUSSELS (Reuters) - NATO allies on Tuesday we...  False news
# 67754  LONDON (Reuters) - LexisNexis, a provider of l...  False news
# 67755  MINSK (Reuters) - In the shadow of disused Sov...  False news
# 67756  MOSCOW (Reuters) - Vatican Secretary of State ...  False news
# 67757  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  False news
#
# [67758 rows x 2 columns]
